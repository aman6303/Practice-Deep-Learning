# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam

# %%
X, y = make_moons(100, noise=0.25,random_state=2)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %% [markdown]
# # Without Regularization

# %%
model1 = Sequential()

model1.add(Input(shape=(2,)))
model1.add(Dense(128,activation="relu"))
model1.add(Dense(128, activation="relu"))
model1.add(Dense(1,activation='sigmoid'))

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = Adam(learning_rate=0.01)
model1.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

history1 = model1.fit(X, y, epochs=200, validation_split = 0.2,verbose=1)
# Out:
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - accuracy: 0.9250 - loss: 0.1969 - val_accuracy: 1.0000 - val_loss: 0.0275
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9250 - loss: 0.2378 - val_accuracy: 1.0000 - val_loss: 0.0582
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9500 - loss: 0.1145 - val_accuracy: 0.9500 - val_loss: 0.6104
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9625 - loss: 0.0769 - val_accuracy: 0.8500 - val_loss: 1.0994
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9375 - loss: 0.2004 - val_accuracy: 0.8500 - val_loss: 0.8306
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9500 - loss: 0.0579 - val_accuracy: 0.9500 - val_loss: 0.5430
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9875 - loss: 0.0417 - val_accuracy: 0.9500 - val_loss: 0.3115
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9750 - loss: 0.0738 - val_accuracy: 0.9500 - val_loss: 0.2445
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9750 - loss: 0.0520 - val_accuracy: 0.9500 - val_loss: 0.3284
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9750 - loss: 0.0394 - val_accuracy: 0.9500 - val_loss: 0.4470
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9750 - loss: 0.0412 - val_accuracy: 0.9000 - val_loss: 0.5878
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9750 - loss: 0.0447 - val_accuracy: 0.9000 - val_loss: 0.6759
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9875 - loss: 0.0384 - val_accuracy: 0.9000 - val_loss: 0.5880
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9750 - loss: 0.0361 - val_accuracy: 0.9500 - val_loss: 0.5212
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9875 - loss: 0.0321 - val_accuracy: 0.9500 - val_loss: 0.4879
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9875 - loss: 0.0330 - val_accuracy: 0.9500 - val_loss: 0.4753
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9875 - loss: 0.0342 - val_accuracy: 0.9500 - val_loss: 0.4724
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9875 - loss: 0.0318 - val_accuracy: 0.9500 - val_loss: 0.4710
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9875 - loss: 0.0315 - val_accuracy: 0.9500 - val_loss: 0.4744
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9875 - loss: 0.0309 - val_accuracy: 0.9500 - val_loss: 0.4800
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9875 - loss: 0.0315 - val_accuracy: 0.9500 - val_loss: 0.4889
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9750 - loss: 0.0358 - val_accuracy: 0.9500 - val_loss: 0.5039
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9875 - loss: 0.0294 - val_accuracy: 0.9500 - val_loss: 0.5098
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9875 - loss: 0.0274 - val_accuracy: 0.9500 - val_loss: 0.5157
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9875 - loss: 0.0315 - val_accuracy: 0.9500 - val_loss: 0.5229
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9875 - loss: 0.0301 - val_accuracy: 0.9500 - val_loss: 0.5340
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9875 - loss: 0.0263 - val_accuracy: 0.9500 - val_loss: 0.5490
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9750 - loss: 0.0362 - val_accuracy: 0.9500 - val_loss: 0.5563
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.
# Epoch 178/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9500 - val_loss: 0.9132
# Epoch 179/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9500 - val_loss: 0.9156
# Epoch 180/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9500 - val_loss: 0.9169
# Epoch 181/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9500 - val_loss: 0.9163
# Epoch 182/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9500 - val_loss: 0.9140
# Epoch 183/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9500 - val_loss: 0.9116
# Epoch 184/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9500 - val_loss: 0.9117
# Epoch 185/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 9.5858e-04 - val_accuracy: 0.9500 - val_loss: 0.9084
# Epoch 186/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9500 - val_loss: 0.9060
# Epoch 187/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9500 - val_loss: 0.9084
# Epoch 188/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 9.7944e-04 - val_accuracy: 0.9500 - val_loss: 0.9164
# Epoch 189/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 9.7280e-04 - val_accuracy: 0.9500 - val_loss: 0.9231
# Epoch 190/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 9.3986e-04 - val_accuracy: 0.9500 - val_loss: 0.9265
# Epoch 191/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 9.2372e-04 - val_accuracy: 0.9500 - val_loss: 0.9288
# Epoch 192/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 1.0000 - loss: 8.8849e-04 - val_accuracy: 0.9500 - val_loss: 0.9315
# Epoch 193/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 9.1382e-04 - val_accuracy: 0.9500 - val_loss: 0.9312
# Epoch 194/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 8.5993e-04 - val_accuracy: 0.9500 - val_loss: 0.9347
# Epoch 195/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 8.6014e-04 - val_accuracy: 0.9500 - val_loss: 0.9388
# Epoch 196/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 8.4745e-04 - val_accuracy: 0.9500 - val_loss: 0.9396
# Epoch 197/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 8.7188e-04 - val_accuracy: 0.9500 - val_loss: 0.9415
# Epoch 198/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 1.0000 - loss: 8.5139e-04 - val_accuracy: 0.9500 - val_loss: 0.9453
# Epoch 199/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 8.4032e-04 - val_accuracy: 0.9500 - val_loss: 0.9464
# Epoch 200/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 1.0000 - loss: 8.7906e-04 - val_accuracy: 0.9500 - val_loss: 0.9478

# %%
plot_decision_regions(X, y.astype('int'), clf=model1, legend=2)
plt.xlim(-2,3)
plt.ylim(-1.5,2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])

# %% [markdown]
# Here, we can clearly see there overfitting is happening after 20+ epochs

# %% [markdown]
# # With L2 regularization

# %%
model2 = Sequential()

model2.add(Dense(128,input_dim=2, activation="relu",kernel_regularizer=tensorflow.keras.regularizers.l2(0.01)))  #l2 regularization with lembda = 0.01
model2.add(Dense(128, activation="relu",kernel_regularizer=tensorflow.keras.regularizers.l2(0.01)))
model2.add(Dense(1,activation='sigmoid'))

model2.summary()
# Out:
# C:\Users\DELL\miniconda3\envs\campusx\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 128)                 │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = Adam(learning_rate=0.01)
model2.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

history2 = model2.fit(X, y, epochs=200, validation_split = 0.2,verbose=0)

# %%
plot_decision_regions(X, y.astype('int'), clf=model2, legend=2)
plt.xlim(-2,3)
plt.ylim(-1.5,2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])

# %% [markdown]
# # Comparing weights before and after regularizaztion

# %%
# getting the weights

model1_weight_layer1 = model1.get_weights()[0].reshape(256)
model2_weight_layer1 = model2.get_weights()[0].reshape(256)

# %%
sns.boxplot(model1_weight_layer1)
# Out:
# <Axes: >

# %%
sns.boxplot(model2_weight_layer1)
# Out:
# <Axes: >

# %% [markdown]
# Most of the weights are centered around 0 due to Regularization

# %%
sns.kdeplot(model1_weight_layer1)
sns.kdeplot(model2_weight_layer1)
# Out:
# <Axes: ylabel='Density'>
